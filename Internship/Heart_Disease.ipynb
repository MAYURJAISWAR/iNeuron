# %%
# Heart Disease dataset EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_disease_dataset=pd.read_csv('D:\iNeuron Data Analytics\Heart Disease\heart.csv')

# %%
print(heart_disease_dataset)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# age
# sex
# chest pain type (4 values)
# resting blood pressure
# serum cholestoral in mg/dl
# fasting blood sugar > 120 mg/dl
# resting electrocardiographic results (values 0,1,2)
# maximum heart rate achieved
# exercise induced angina
# oldpeak = ST depression induced by exercise relative to rest
# the slope of the peak exercise ST segment
#         number of major vessels (0-3) colored by flourosopy
#         thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
#         The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %%
heart_disease_dataset_copy=heart_disease_dataset.copy()

# %%
print(heart_disease_dataset_copy)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
print(heart_disease_dataset_copy.head()) # Top 5 rows
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print(heart_disease_dataset_copy.tail()) # Bottom 5 columns
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
print(heart_disease_dataset_copy.shape) # Number of rows and columns
# Out:
# (1025, 14)

# %%
print(heart_disease_dataset_copy.columns) # Columns in dataset
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
print(heart_disease_dataset_copy.info()) # Gives information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None

# %%
print(heart_disease_dataset_copy.describe()) # Statistical information of the dataset
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
print(heart_disease_dataset_copy.dtypes)
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# age, cp are  categorical column,

# %%
print(heart_disease_dataset_copy.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data_duplicate=heart_disease_dataset_copy.duplicated().any()
print(data_duplicate)
# Out:
# True

# %%
heart_disease_dataset_copy=heart_disease_dataset_copy.drop_duplicates()

# %%
print(heart_disease_dataset_copy.shape) # As  you can see the shape has got change means the duplicates has been removed
# Out:
# (302, 14)

# %%
print(heart_disease_dataset_copy.corr())
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
sns.set()
plt.subplots(figsize=(10,20))
sns.heatmap(heart_disease_dataset_copy.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
heart_disease_dataset_copy['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
print(sns.countplot(heart_disease_dataset_copy['target']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# From the above diagram it has observed that more people are chance to heart attack

# %%
heart_disease_dataset_copy['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(heart_disease_dataset_copy['sex'])
plt.xticks([0,1],['Female','Male'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# From above diagram total number of  male and female are 206 and 96 respectively

# %%
print(heart_disease_dataset_copy.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue='target',data=heart_disease_dataset_copy)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-disease','Disease'])
plt.show()

# %% [markdown]
# Therefore from above chart, it has been observed that men are more prone to heart disease

# %%
sns.histplot(heart_disease_dataset_copy['age'])
plt.show()

# %% [markdown]
# From above histogram chart, people between 50 to 60 years are more prone to heart disease

# %%
sns.countplot(heart_disease_dataset_copy['cp'])
plt.xticks([0,1,2,3],['typical angina','atypical angina','non-aginal pain','asymptomatic'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Typical angina chest pain are more common between people

# %%
sns.countplot(x='cp',hue='target',data=heart_disease_dataset_copy)
plt.legend(labels=['No-disease','Disease'])
plt.show()

# %%
sns.countplot(x='fbs',hue='target',data=heart_disease_dataset_copy)
plt.legend(labels=['No-disease','Disease'])
plt.show()

# %%
heart_disease_dataset_copy['trestbps'].hist()
plt.show()

# %% [markdown]
# Resting blood pressure is mostly between 120 to 140

# %%
g=sns.FacetGrid(heart_disease_dataset_copy,hue='sex',aspect=4)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Female'])
plt.show()

# %% [markdown]
# From above graph it is observed women have less resting blood pressure compared to men

# %%
heart_disease_dataset_copy['chol'].hist()
plt.show()

# %%
categorical_values=[]
continuous_values=[]
for column in heart_disease_dataset_copy.columns:
    if heart_disease_dataset_copy[column].nunique()<=10:
        categorical_values.append(column)
    else:
        continuous_values.append(column)

# %%
print(categorical_values)
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
print(continuous_values)
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
heart_disease_dataset_copy.hist(continuous_values,figsize=(15,6))
plt.tight_layout()
plt.show()
